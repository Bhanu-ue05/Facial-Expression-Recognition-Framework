# %% [markdown]
# # Facial Expression Recognition Using Deep Convolutional Neural Networks and Transfer Learning on RAF-DB
#
# **Student:** Bhanu Prasad Mudraboina
# **Course:** Machine Learning
# **Instructor:** Raja Hashmi Ali
# **Dataset:** RAF-DB (Real-world Affective Faces Database)
#
# ## Project Overview
# This project develops a facial expression recognition framework using a custom CNN and transfer learning models (ResNet50 and MobileNetV2) on the RAF-DB dataset.
#
# ## Research Objectives
# - Develop a CNN model for facial expression recognition
# - Compare CNN with transfer learning models
# - Evaluate using accuracy, precision, recall, F1-score, confusion matrix, ROC-AUC and Grad-CAM

# %% [markdown]
# ## Dataset Paths
# Update paths if required:
# ```python
# train_dir = '/kaggle/input/datasets/shuvoalok/raf-db-dataset/DATASET/train'
# test_dir = '/kaggle/input/datasets/shuvoalok/raf-db-dataset/DATASET/test'
# ```
